# %% [markdown]
# # Data visualistation with matplotlib

# %% [markdown]
# ## 1. Import matplotlib modules

# %%
import matplotlib

# %% [markdown]
# Matplotlib has many different backends, usually its fine to stick to the default. But sometimes it is necessary to change the backend (before importing the plotting module ```pyplot```). The full list of available backends reads:

# %% [markdown]
# [u'pgf', u'cairo', u'MacOSX', u'CocoaAgg', u'gdk', u'ps', u'GTKAgg', u'nbAgg', u'GTK', u'Qt5Agg', u'template', u'emf', u'GTK3Cairo', u'GTK3Agg', u'WX', u'Qt4Agg', u'TkAgg', u'agg', u'svg', u'GTKCairo', u'WXAgg', u'WebAgg', u'pdf']

# %% [markdown]
# When working from within a jupyter notebook, we can choose *matplotlib* backend with a magic function

# %%
# %matplotlib --list
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'gtk4', 'wx', 'qt4', 'qt5', 'qt6', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %%
# %matplotlib inline
#% matplotlib notebook

# %% [markdown]
# Now, we import ```pyplot``` the main plotting module of *matplotlib*

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. The default plot

# %% [markdown]
# Let's create some data (normal distribution)

# %%
import numpy as np
data = np.random.normal(loc=5., scale=2., size=(10000,))

# %% [markdown]
# and plot a simple histogram of our data

# %%
fig = plt.figure()
ax  = fig.add_subplot(111)
ax.hist(data, range=(-5,15), bins=20, density=True)
plt.show()

# %% [markdown]
# ## 3. Adding more to the plot

# %% [markdown]
# First, we are going to fit a Gaussian profile to our function

# %%
from scipy.stats import norm
mu,sigma = norm.fit(data)

# %% [markdown]
# and plot it on top of our histogram

# %%
fig = plt.figure()
ax  = fig.add_subplot(111)
ax.hist(data, range=(-5,15), bins=20, density=True)
ax.plot(np.arange(-5,15,0.1),norm.pdf(np.arange(-5,15,0.1),mu,sigma))
plt.show()

# %% [markdown]
# let's make a bit easier to read (colors, legends, axis lables, etc..)

# %%
fig = plt.figure()
ax  = fig.add_subplot(111)
ax.set_title('My fancy plot')
ax.hist(data, range=(-5,15), bins=20, density=True, label='data')
ax.plot(np.arange(-5,15,0.1),norm.pdf(np.arange(-5,15,0.1),mu,sigma), label='fit', color='r')
ax.set_xlabel(r'Some variable $\varphi$')
ax.set_ylabel(r'Probability density')
ax.legend(loc=1)
plt.show()

# %% [markdown]
# ## 4. More changes to the plot

# %% [markdown]
# Our plot looks already quite good, but some of the features don't give any extra information so why not removing them

# %%
fig = plt.figure()
ax  = fig.add_subplot(111)
ax.set_title('My fancy plot')
ax.hist(data, range=(-5,15), bins=20, density=True, label='data')
ax.plot(np.arange(-5,15,0.1),norm.pdf(np.arange(-5,15,0.1),mu,sigma), label='fit', color='r')
ax.set_xlabel(r'Some variable $\varphi$')
ax.legend(loc=2, frameon=False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='x', which='both', bottom='on', top='off')
ax.tick_params(axis='y', which='both', left='off', right='off', labelleft='off')
plt.show()

# %% [markdown]
# ## 5. Saving the plot as a PDF

# %%
fig = plt.figure()
ax  = fig.add_subplot(111)
ax.set_title('My fancy plot')
ax.hist(data, range=(-5,15), bins=20, density=True, label='data')
ax.plot(np.arange(-5,15,0.1),norm.pdf(np.arange(-5,15,0.1),mu,sigma), label='fit', color='r')
ax.set_xlabel(r'Some variable $\varphi$')
ax.legend(loc=2, frameon=False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='x', which='both', bottom='on', top='off')
ax.tick_params(axis='y', which='both', left='off', right='off', labelleft='off')
fig.savefig('my_fancy_plot.pdf', format='pdf', bbox_inches='tight')

# %%
# A simple program illustrating chaotic behaviour
#from mpl_toolkits import mplot3d
#%matplotlib inline

#def main(x):
#    data = []
#    for i in range(100):
#        x = 3.9 * x * (1-x)
#        data.append(x)
#    return data
        #print (x)

#data = main(0.1)
#plt.plot(data)

from mpl_toolkits import mplot3d

# Define the data

mass85  = [(100.823   , 92.3064   , 83.794    , 75.2887   , 66.7897   , 58.2987   , 49.8174   ), (3.46104   , 3.30607   , 3.19176   , 3.0241    , 2.81563   , 2.57809   , 2.34708   ), (85)]
mass136 = [(78.2452   , 68.2923   , 58.3575   , 48.4429   , 38.5683   ), (2.98233   , 2.74343   , 2.4783    , 2.18797   , 1.85667   ), (136)]
mass143 = [(31.6586   , 42.4732   , 53.3472   , 64.2561   ), (1.56013   , 1.96295   , 2.3074    , 2.61546   ), (143)]

# Create the figure and axis
fig = plt.figure()
ax = plt.axes(projection='3d')

# Plot the data
ax.scatter(mass85[0], mass85[1], mass85[2], c='green', marker='*')
ax.scatter(mass136[0], mass136[1], mass136[2], c='blue', marker='o')
ax.scatter(mass143[0], mass143[1], mass143[2], c='red', marker='^')

# Set the axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Show the plot
plt.show()


fig, ax = plt.subplots()

ax.scatter( [d[1] for d in mass85 ], [d[2] for d in mass85 ], c='green', marker='*')
ax.scatter( [d[1] for d in mass136], [d[2] for d in mass136], c='blue', marker='o')
ax.scatter( [d[1] for d in mass143], [d[2] for d in mass143], c='red', marker='^')

ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [76], in <cell line: 44>()
#      39 plt.show()
#      42 fig, ax = plt.subplots()
# ---> 44 ax.scatter( mass85[1], mass85[2], c='green', marker='*')
#      46 ax.set_ylabel('Y')
#      47 ax.set_zlabel('Z')
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4368, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4366 y = np.ma.ravel(y)
#    4367 if x.size != y.size:
# -> 4368     raise ValueError("x and y must be the same size")
#    4370 if s is None:
#    4371     s = (20 if rcParams['_internal.classic_mode'] else
#    4372          rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size
